# %% [markdown]
# <a href="https://colab.research.google.com/github/kim-spirit/aipython/blob/main/0524_%EC%97%B0%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
wine_load = load_wine() #load wine 꼭 신경쓸 것
wine = pd.DataFrame(wine_load.data, columns=wine_load.feature_names)
wine['Class'] = wine_load.target
wine['Class'] = wine['Class'].map({0:'class_0',1:'class_1',2:'class_2'})
import matplotlib.pyplot as plt
plt.boxplot(wine['color_intensity'], whis=1.5)
plt.title('color_intensity')
plt.show()

# %%
import pandas as pd
df=pd.read_csv('iris.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
import pandas as pd
df2=pd.read_csv('penguins.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df2.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df2.dropna(how='any')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df[df2.duplicated()]
# Out:
# <ipython-input-54-8cc6580aa2e1>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df2.duplicated()]
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %%
df[df.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 142           5.8          2.7           5.1          1.9  virginica

# %%
df3=df.drop_duplicates()

# %%
df2.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df2.sort_values(by=['body_mass_g'], ascending=True)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 190  Chinstrap      Dream            46.9           16.6              192.0
# 64      Adelie     Biscoe            36.4           17.1              184.0
# 58      Adelie     Biscoe            36.5           16.6              181.0
# 116     Adelie  Torgersen            38.6           17.0              188.0
# 98      Adelie      Dream            33.1           16.1              178.0
# ..         ...        ...             ...            ...                ...
# 337     Gentoo     Biscoe            48.8           16.2              222.0
# 253     Gentoo     Biscoe            59.6           17.0              230.0
# 237     Gentoo     Biscoe            49.2           15.2              221.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 339     Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g     sex
# 190       2700.0  FEMALE
# ...

# %%
plt.scatter(x=df2['body_mass_g'], y=df2['flipper_length_mm'])
plt.xlabel('body_mass_g')
plt.ylabel('flipper_length_mm')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


plt.boxplot(df2['body_mass_g'].dropna(), whis=1.5)
plt.title('penguins_body_mass')
plt.show()

# %%
#이상치 데이터의 위치와 값 확읺하기
import numpy as np
quartile_1, quartile_3 = np.percentile(df2['body_mass_g'], [25,75])
iqr = quartile_3 - quartile_1
upper_whis = quartile_3 + 1.5*iqr
lower_whis = quartile_1 - 1.5*iqr
outliers = df2[(df2['body_mass_g'] < lower_whis) | (df2['body_mass_g'] > upper_whis)]
print(outliers)
print(outliers.index)
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex]
# Index: []
# Index([], dtype='int64')

# %%
drop_outliers = df2.drop(index=outliers.index)
print('outliers : ', df2.shape)
print('Drop outliers : ', drop_outliers.shape)
# Out:
# outliers :  (344, 7)
# Drop outliers :  (344, 7)

# %%
df2.loc[outliers.index, 'body_mass_g'] = df2['body_mass_g'].dropna().mean()
df2.loc[outliers.index, 'body_mass_g']
# Out:
# Series([], Name: body_mass_g, dtype: float64)
